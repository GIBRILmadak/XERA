# %%
pip install torch
# Out:
# ...
#    ━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.4/530.7 MB 27.4 kB/s eta 4:44:04m
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/home/g/.config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/pip/_vendor/urllib3/response.py", line 438, in _error_catcher
#     yield
#   File "/home/g/.config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/pip/_vendor/urllib3/response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/g/.config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/pip/_vendor/urllib3/response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/g/.config/jupyterlab-desktop/jlab_server/lib/python3.12/site-packages/pip/_vendor/cachecontrol/filewrapper.py", line 98, in read
#     data: bytes = self.__fp.read(amt)
#                   ^^^^^^^^^^^^^^^^^^^
# ...
